# %%
import matplotlib.pyplot as plt
import matplotlib.dates as md
import seaborn as sns
import pandas as pd
from scipy.stats import t
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
btc = pd.read_csv('btc_prediction_datawranglingStage.csv', parse_dates=True)
sns.set(style='ticks')

# %%
btc.shape
# Out:
# (49083, 7)

# %%
btc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49083 entries, 0 to 49082
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              49083 non-null  object
#  1   open              49083 non-null  float64
#  2   high              49083 non-null  float64
#  3   low               49083 non-null  float64
#  4   close             49083 non-null  float64
#  5   quoteAssetVolume  49083 non-null  float64
#  6   TBQuoteVolume     49083 non-null  float64
# dtypes: float64(6), object(1)
# memory usage: 2.6+ MB

# %%
btc.head()
# Out:
#                   Date     open     high      low    close  quoteAssetVolume  \
# 0  2017-08-17 04:00:00  4261.48  4313.62  4261.32  4308.83     202366.138393
# 1  2017-08-17 05:00:00  4308.83  4328.69  4291.37  4315.32     100304.823567
# 2  2017-08-17 06:00:00  4330.29  4345.45  4309.37  4324.35      31282.312670
# 3  2017-08-17 07:00:00  4316.62  4349.99  4287.41  4349.99      19241.058300
# 4  2017-08-17 08:00:00  4333.32  4377.85  4333.32  4360.69       4239.503586
#
#    TBQuoteVolume
# 0  150952.477943
# 1   92608.279728
# 2   20795.317224
# 3   11291.347015
# 4    3552.746817

# %%
mean = round(np.mean(btc.close), 2)
std = round(np.std(btc.close, ddof=1),2)
print('Mean:', mean,
      '\nStd:', std)
# Out:
# Mean: 19573.75
# Std: 16397.98

# %%
sns.pairplot(btc)

# %%
sns.boxplot(btc)
# Out:
# <Axes: >

# %%
sns.heatmap(btc.corr(), annot=True)
# Out:
# /var/folders/q7/1k7jcrmx4rv8bqn_fgk78smm0000gn/T/ipykernel_1990/3386791408.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(btc.corr(), annot=True)
# <Axes: >

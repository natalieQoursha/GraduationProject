# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
btc = pd.read_csv('btc_prediction_datawranglingStage.csv')

# %%
#btc['year'] = pd.DatetimeIndex(btc['Date']).year
#btc['month'] = pd.DatetimeIndex(btc['Date']).month
#btc['day'] = pd.DatetimeIndex(btc['Date']).day
#btc['hour'] = pd.DatetimeIndex(btc['Date']).hour

btc.drop(columns=['Date'], inplace=True)

# %%
btc.head()
# Out:
#       open     high      low    close       volume
# 0  4261.48  4485.39  4200.74  4285.08   795.150377
# 1  4285.08  4371.52  3938.77  4108.37  1199.888264
# 2  4108.37  4184.69  3850.00  4139.98   381.309763
# 3  4120.98  4211.08  4032.62  4086.29   467.083022
# 4  4069.13  4119.62  3911.79  4016.00   691.743060

# %%
target = btc['close'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(btc, target, test_size=0.3, random_state=0)

# %%
btc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2059 entries, 0 to 2058
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    2059 non-null   float64
#  1   high    2059 non-null   float64
#  2   low     2059 non-null   float64
#  3   close   2059 non-null   float64
#  4   volume  2059 non-null   float64
# dtypes: float64(5)
# memory usage: 80.6 KB

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('Mean Squared Error:', mse)
print('R-squared:', r2)
# Out:
# Mean Squared Error: 1.3912762974355693e-22
# R-squared: 1.0

# %%
import matplotlib.pyplot as plt
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend()
plt.show()
